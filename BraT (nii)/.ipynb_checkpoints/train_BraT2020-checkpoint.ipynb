# %%
import os
import numpy as np
from custom_datagen import imageLoader
#import tensorflow as tf
import keras
from matplotlib import pyplot as plt
import glob
import random
# Out:
# Using TensorFlow backend.

# %%
train_img_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\train\\images\\"
train_mask_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\train\\masks\\"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))

# %%
img_list
# Out:
# ['image_0.npy',
#  'image_1.npy',
#  'image_10.npy',
#  'image_100.npy',
#  'image_101.npy',
#  'image_102.npy',
#  'image_103.npy',
#  'image_104.npy',
#  'image_105.npy',
#  'image_106.npy',
#  'image_108.npy',
#  'image_11.npy',
#  'image_110.npy',
#  'image_111.npy',
#  'image_112.npy',
#  'image_113.npy',
#  'image_114.npy',
#  'image_115.npy',
#  'image_116.npy',
#  'image_117.npy',
#  'image_118.npy',
#  'image_119.npy',
#  'image_12.npy',
#  'image_120.npy',
#  'image_122.npy',
#  'image_123.npy',
#  'image_124.npy',
#  'image_125.npy',
#  'image_126.npy',
#  'image_127.npy',
#  'image_128.npy',
#  'image_129.npy',
#  'image_13.npy',
#  'image_130.npy',
#  'image_131.npy',
#  'image_132.npy',
#  'image_133.npy',
#  'image_134.npy',
#  'image_135.npy',
#  'image_136.npy',
#  'image_137.npy',
#  'image_139.npy',
#  'image_14.npy',
#  'image_140.npy',
#  'image_142.npy',
#  'image_143.npy',
#  'image_144.npy',
#  'image_145.npy',
#  'image_146.npy',
#  'image_147.npy',
# ...

# %%
msk_list
# Out:
# ['mask_0.npy',
#  'mask_1.npy',
#  'mask_10.npy',
#  'mask_100.npy',
#  'mask_101.npy',
#  'mask_102.npy',
#  'mask_103.npy',
#  'mask_104.npy',
#  'mask_105.npy',
#  'mask_106.npy',
#  'mask_108.npy',
#  'mask_11.npy',
#  'mask_110.npy',
#  'mask_111.npy',
#  'mask_112.npy',
#  'mask_113.npy',
#  'mask_114.npy',
#  'mask_115.npy',
#  'mask_116.npy',
#  'mask_117.npy',
#  'mask_118.npy',
#  'mask_119.npy',
#  'mask_12.npy',
#  'mask_120.npy',
#  'mask_122.npy',
#  'mask_123.npy',
#  'mask_124.npy',
#  'mask_125.npy',
#  'mask_126.npy',
#  'mask_127.npy',
#  'mask_128.npy',
#  'mask_129.npy',
#  'mask_13.npy',
#  'mask_130.npy',
#  'mask_131.npy',
#  'mask_132.npy',
#  'mask_133.npy',
#  'mask_134.npy',
#  'mask_135.npy',
#  'mask_136.npy',
#  'mask_137.npy',
#  'mask_139.npy',
#  'mask_14.npy',
#  'mask_140.npy',
#  'mask_142.npy',
#  'mask_143.npy',
#  'mask_144.npy',
#  'mask_145.npy',
#  'mask_146.npy',
#  'mask_147.npy',
#  'mask_148.npy',
#  'mask_149.npy',
#  'mask_15.npy',
# ...

# %%
img_num = random.randint(0,num_images-1)
test_img = np.load(train_img_dir+img_list[img_num])
test_mask = np.load(train_mask_dir+msk_list[img_num])
test_mask = np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %% [markdown]
# # Optional Step

# %%
import pandas as pd
columns = ['0','1', '2', '3']
df = pd.DataFrame(columns=columns)
train_mask_list = sorted(glob.glob('BraT(nii)/input_data_128/train/masks/*.npy'))
print(train_mask_list)
for img in range(len(train_mask_list)):
    print(img)
    temp_image=np.load(train_mask_list[img])
    temp_image = np.argmax(temp_image, axis=3)
    val, counts = np.unique(temp_image, return_counts=True)
    zipped = zip(columns, counts)
    conts_dict = dict(zipped)
    
    df = df.append(conts_dict, ignore_index=True)

label_0 = df['0'].sum()
label_1 = df['1'].sum()
label_2 = df['1'].sum()
label_3 = df['3'].sum()
total_labels = label_0 + label_1 + label_2 + label_3
n_classes = 4
#Class weights claculation: n_samples / (n_classes * n_samples_for_class)
wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
wt1 = round((total_labels/(n_classes*label_1)), 2)
wt2 = round((total_labels/(n_classes*label_2)), 2)
wt3 = round((total_labels/(n_classes*label_3)), 2)
# Out:
# []
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-27-c9b7ee3e697f> in <module>
#      21 n_classes = 4
#      22 #Class weights claculation: n_samples / (n_classes * n_samples_for_class)
# ---> 23 wt0 = round((total_labels/(n_classes*label_0)), 2) #round to 2 decimals
#      24 wt1 = round((total_labels/(n_classes*label_1)), 2)
#      25 wt2 = round((total_labels/(n_classes*label_2)), 2)
#
# ZeroDivisionError: division by zero

# %%
train_img_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\train\\images\\"
train_mask_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\train\\masks\\"

val_img_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\val\\images\\"
val_mask_dir = r"D:\\BraT(nii)\\BraTS2020_TrainingData\\input_data_128\\val\\masks\\"

train_img_list=os.listdir(train_img_dir)
train_mask_list = os.listdir(train_mask_dir)

val_img_list=os.listdir(val_img_dir)
val_mask_list = os.listdir(val_mask_dir)

# %%
train_img_list
# Out:
# ['image_0.npy',
#  'image_1.npy',
#  'image_10.npy',
#  'image_100.npy',
#  'image_101.npy',
#  'image_102.npy',
#  'image_103.npy',
#  'image_104.npy',
#  'image_105.npy',
#  'image_106.npy',
#  'image_108.npy',
#  'image_11.npy',
#  'image_110.npy',
#  'image_111.npy',
#  'image_112.npy',
#  'image_113.npy',
#  'image_114.npy',
#  'image_115.npy',
#  'image_116.npy',
#  'image_117.npy',
#  'image_118.npy',
#  'image_119.npy',
#  'image_12.npy',
#  'image_120.npy',
#  'image_122.npy',
#  'image_123.npy',
#  'image_124.npy',
#  'image_125.npy',
#  'image_126.npy',
#  'image_127.npy',
#  'image_128.npy',
#  'image_129.npy',
#  'image_13.npy',
#  'image_130.npy',
#  'image_131.npy',
#  'image_132.npy',
#  'image_133.npy',
#  'image_134.npy',
#  'image_135.npy',
#  'image_136.npy',
#  'image_137.npy',
#  'image_139.npy',
#  'image_14.npy',
#  'image_140.npy',
#  'image_142.npy',
#  'image_143.npy',
#  'image_144.npy',
#  'image_145.npy',
#  'image_146.npy',
#  'image_147.npy',
# ...

# %%
val_img_list
# Out:
# ['image_277.npy',
#  'image_278.npy',
#  'image_279.npy',
#  'image_280.npy',
#  'image_281.npy',
#  'image_282.npy',
#  'image_283.npy',
#  'image_284.npy',
#  'image_285.npy',
#  'image_286.npy',
#  'image_287.npy',
#  'image_288.npy',
#  'image_289.npy',
#  'image_290.npy',
#  'image_291.npy',
#  'image_292.npy',
#  'image_293.npy',
#  'image_294.npy',
#  'image_295.npy',
#  'image_296.npy',
#  'image_297.npy',
#  'image_298.npy',
#  'image_299.npy',
#  'image_300.npy',
#  'image_301.npy',
#  'image_302.npy',
#  'image_303.npy',
#  'image_304.npy',
#  'image_305.npy',
#  'image_306.npy',
#  'image_307.npy',
#  'image_308.npy',
#  'image_309.npy',
#  'image_310.npy',
#  'image_311.npy',
#  'image_312.npy',
#  'image_314.npy',
#  'image_315.npy',
#  'image_317.npy',
#  'image_318.npy',
#  'image_319.npy',
#  'image_320.npy',
#  'image_321.npy',
#  'image_322.npy',
#  'image_323.npy',
#  'image_325.npy',
#  'image_326.npy',
#  'image_327.npy',
#  'image_328.npy',
#  'image_329.npy',
# ...

# %%
batch_size = 2

train_img_datagen = imageLoader(train_img_dir, train_img_list, 
                                train_mask_dir, train_mask_list, batch_size)

val_img_datagen = imageLoader(val_img_dir, val_img_list, 
                                val_mask_dir, val_mask_list, batch_size)

#Verify generator.... In python 3 next() is renamed as __next__()
img, msk = train_img_datagen.__next__()

img_num = random.randint(0,img.shape[0]-1)
test_img=img[img_num]
test_mask=msk[img_num]
test_mask=np.argmax(test_mask, axis=3)

n_slice=random.randint(0, test_mask.shape[2])
plt.figure(figsize=(12, 8))

plt.subplot(221)
plt.imshow(test_img[:,:,n_slice, 0], cmap='gray')
plt.title('Image flair')
plt.subplot(222)
plt.imshow(test_img[:,:,n_slice, 1], cmap='gray')
plt.title('Image t1ce')
plt.subplot(223)
plt.imshow(test_img[:,:,n_slice, 2], cmap='gray')
plt.title('Image t2')
plt.subplot(224)
plt.imshow(test_mask[:,:,n_slice])
plt.title('Mask')
plt.show()

# %%
print(img.shape)
# Out:
# (2, 128, 128, 128, 3)

# %%
print(msk.shape)
# Out:
# (2, 128, 128, 128, 4)

# %%
# !pip install segmentation-models-3D --user

# %%
wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
import segmentation_models_3D as sm
dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3])) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = ['accuracy', sm.metrics.IOUScore(threshold=0.5)]

LR = 0.0001
optim = keras.optimizers.Adam(LR)
# Out:
# Segmentation Models: using `tf.keras` framework.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-48-694dc94e96b4> in <module>
#       1 wt0, wt1, wt2, wt3 = 0.25,0.25,0.25,0.25
#       2 import tensorflow as tf
# ----> 3 import segmentation_models_3D as sm
#       4 dice_loss = sm.losses.DiceLoss(class_weights=np.array([wt0, wt1, wt2, wt3]))
#       5 focal_loss = sm.losses.CategoricalFocalLoss()
#
# ~\anaconda3\lib\site-packages\segmentation_models_3D\__init__.py in <module>
#     107
#     108 # wrap segmentation models with framework modules
# --> 109 from .backbones.backbones_factory import Backbones
#     110 from .models.unet import Unet as _Unet
#     111 from .models.pspnet import PSPNet as _PSPNet
#
# ~\anaconda3\lib\site-packages\segmentation_models_3D\backbones\backbones_factory.py in <module>
#       1 import copy
# ...
